# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
pwd
# Out:
# 'C:\\Users\\Emre\\Downloads\\web_scraping_workshop'

# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Emre\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from selenium.webdriver.common.keys import Keys

from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

#driver = webdriver.Chrome()
driver.get("https://www.ajc.com/senior-care-quality-report/homes/")
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# There is no [win32] chromedriver for browser  in cache
# ...

# %%
soup = BeautifulSoup(driver.page_source, "lxml")

# %%
soup.find(class_="table b-table").find_all("a")
# Out:
# [<a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#          Addington Place at the Mills
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-alpharetta/">
#          Addington Place of Alpharetta
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-brunswick/">
#          Addington Place of Brunswick
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-dublin/">
#          Addington Place of Dublin
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-johns-creek/">
#          Addington Place of Johns Creek
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/alto-senior-living-alpharetta/">
# ...

# %%
# there are 398 facilities
len(soup.find(class_="table b-table").find_all("a"))
# Out:
# 398

# %%
html_file = open(file = "test.html", mode = "w", encoding = "utf-8")
html_file.write(soup.text)
html_file.close()

# %% [markdown]
# # Populating Facilities' Main Info

# %%
flagged = []
name = []
hometype = []
beds = []

count = 0
rates = {}

for tr in soup('tr'):
    #Record the name of facility
    try: name = name + [str.rstrip(tr('td')[1].text).lstrip()]
    except: name = name + [""]
    
    #Check flagged status and save:
    try:
        flagged = flagged + [1 if tr('td')[0]('span')[0]('div')[0]['name']=='md-flag-icon' else 0]
    except:
        flagged = flagged + [0]
        
    #Record home type
    try: hometype = hometype + [tr('td')[2]('svg')[0]['data-icon']]
    #hometype = hometype + ['Personal care home' if soup('tr')[1]('td')[2]('svg')[0]['data-icon']=='building' else 'Assisted Living']
    except: hometype = hometype + [""]
        
    #Save number of beds:
    try: beds = beds + [tr('td')[3].text.rstrip().lstrip()]
    except: beds = beds + [""]

    count+=1
    
print(count)
facilities = [name, flagged, hometype, beds]
# Out:
# 399

# %%
#Now we write our data to a csv file:
import csv

# field names  
fields = ['Name', 'Flagged', 'Hometype', 'Beds']  
facilities_rows = zip(*facilities)

filename = "ajc_facilities.csv"

# writing to csv file  
with open(filename, 'w', newline='') as csvfile:  
    # creating a csv writer object  
    csvwriter = csv.writer(csvfile)  
        
    # writing the fields  
    csvwriter.writerow(fields)  
        
    # writing the data rows  
    csvwriter.writerows(facilities_rows)

# %%
import pandas 
  
# reading the CSV file 
facilities_data = pandas.read_csv('ajc_facilities.csv') 
  
# displaying the contents of the CSV file 
facilities_data.head(10)
# Out:
#                              Name  Flagged  Hometype Beds
# 0                             NaN        0       NaN  NaN
# 1    Addington Place at the Mills        1  building   75
# 2   Addington Place of Alpharetta        1  hospital  105
# 3    Addington Place of Brunswick        0  hospital   65
# 4       Addington Place of Dublin        0  hospital   72
# 5  Addington Place of Johns Creek        0  hospital   72
# 6   Alto Senior Living Alpharetta        0  hospital   83
# 7     Alto Senior Living Buckhead        0  hospital   83
# 8     Alto Senior Living Marietta        0  hospital   62
# 9      Antebellum Arlington Place        1  building  120

# %% [markdown]
# # Click the first facility link to open its page

# %%
driver.find_element_by_xpath("//a[@class='list-item-name']").click()   

#<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">
#        Addington Place at the Mills
#      </a>

# %%
driver.find_element_by_xpath("//a[@class='list-item-name']").click()

# %%
driver.current_url
# Out:
# 'https://www.ajc.com/senior-care-quality-report/homes/addington-place-at-the-mills/'

# %%
driver.find_element_by_xpath("//a[@class='list-item-name']").get_attribute('innerHTML')
# Out:
# '\n        Addington Place at the Mills\n      '

# %%
driver.find_element_by_xpath("//a[@class='list-item-name']").get_attribute('outerHTML')
# Out:
# '<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">\n        Addington Place at the Mills\n      </a>'

# %%
get_div = driver.find_element_by_class_name('list-item-name')
get_div.get_attribute('outerHTML')
# Out:
# '<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">\n        Addington Place at the Mills\n      </a>'

# %%
get_div = driver.find_element_by_partial_link_text('Addington')
get_div.get_attribute('outerHTML')
# Out:
# '<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">\n        Addington Place at the Mills\n      </a>'

# %%
link_list = driver.find_elements_by_css_selector('.list-item-name')
link_list[0].get_attribute('outerHTML')
# Out:
# '<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">\n        Addington Place at the Mills\n      </a>'

# %%
#below code clicks 4th facility (Addington Place of Dublin) link:
link_list[3].click()

# %%
driver.current_url
# Out:
# 'https://www.ajc.com/senior-care-quality-report/homes/addington-place-of-dublin/'

# %%
facilitypage = BeautifulSoup(driver.page_source, "lxml")

# %%
facilitypage
# Out:
# <html><head><style>.gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}
# </style><link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans:400,500,700" rel="stylesheet" type="text/css"/><style>.gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
# </style><style>.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
# ...

# %%
facilitypage.find(class_='h3').text
# Out:
# '\n          Addington Place of Dublin\n        '

# %%
facilitypage.find(class_='pt-2').text
# Out:
# '212 Fairview Park Dr, Dublin, GA 31021'

# %%
#facility-details > div.row.facility > div:nth-child(2) > p.pb-md-4
facilitypage.find(class_='pb-md-4').text
# Out:
# 'License: ALC000214  Beds: 72   \n            website\n            '

# %%
facilitypage.find(class_='pb-md-4').find(name = 'a')['href']
# Out:
# 'https://www.cedarhurstliving.com/location/addington-place-dublin/'

# %%
#Get Violations per routine inspection for this facility
#<text class="annotation" x="1.1986751556396484" y="87.33332824707031">This home</text>
#<text class="annotation" x="20.69867515563965" y="103.33332824707031">0.8</text>
facilitypage.find_all(class_='annotation')[1].text
# Out:
# '0.8'

# %%
for row in facilitypage.find_all(class_='inspections-tr'): print(row.text), print("Hi\n")
# Out:
#         11/20/18
#
#         routine
#
#           -
#
#           Show details
#
# Hi
#
#
#         7/5/17
#
#         routine
#
#           -
#
#           Show details
#
# Hi
#
#
#         2/14/17
#
#         routine
#
#           -
#
#           Show details
#
# Hi
#
#
#         11/18/15
#
#         other
#
#           -
#
#           Show details
#
# Hi
#
#
#         8/27/15
#
#         routine
#
#           -
#
#           Show details
#
# Hi
#
#
#           Previous name
#
#         BENTON HOUSE OF DUBLIN
#
# Hi
#
#
#         5/11/15
#
#         routine
#
#           4
#
#           Show details
#
# Hi

# %%
facilitypage.find_all(class_='inspections-tr')[0] #.text #find(name = 'p')
# Out:
# <tr class="inspections-tr no-violations text-muted table-secondary" role="row"><td aria-colindex="1" class="" role="cell"><span data-v-ee0ef674="">
#         11/20/18
#       </span></td><td aria-colindex="2" class="" role="cell"><span class="capitalize" data-v-ee0ef674="">
#         routine
#       </span></td><td aria-colindex="3" class="" role="cell"><span data-v-ee0ef674=""><span data-v-ee0ef674="">
#           -
#         </span></span></td><td aria-colindex="4" class="text-right mx-0 px-0" role="cell"><span data-v-ee0ef674=""><button class="btn details-btn btn-secondary btn-sm" data-v-ee0ef674="" type="button">
#           Show details
#         </button></span></td></tr>

# %%
facilitypage.find(id="__BVID__3175")
# Out:
# <table aria-busy="false" aria-colcount="4" class="table b-table" id="__BVID__3175"><!-- --><!-- --><thead class="" role="rowgroup"><!-- --><tr role="row"><th aria-colindex="1" class="" role="columnheader" scope="col">Date</th><th aria-colindex="2" class="" role="columnheader" scope="col">Type</th><th aria-colindex="3" class="px-0 px-sm-2" role="columnheader" scope="col">Violations</th><th aria-colindex="4" aria-label="Show Details" class="text-right m-0 px-0" role="columnheader" scope="col"></th></tr></thead><!-- --><tbody class="" role="rowgroup"><!-- --><tr class="inspections-tr no-violations text-muted table-secondary" role="row"><td aria-colindex="1" class="" role="cell"><span data-v-ee0ef674="">
#         11/20/18
#       </span></td><td aria-colindex="2" class="" role="cell"><span class="capitalize" data-v-ee0ef674="">
#         routine
#       </span></td><td aria-colindex="3" class="" role="cell"><span data-v-ee0ef674=""><span data-v-ee0ef674="">
#           -
# ...

# %%
driver.find_element_by_css_selector('.inspections-tr').get_attribute("outerHTML")
#<button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#          Show details
#        </button>
# Out:
# '<tr role="row" class="inspections-tr no-violations text-muted table-secondary"><td role="cell" aria-colindex="1" class=""><span data-v-ee0ef674="">\n        11/20/18\n      </span></td><td role="cell" aria-colindex="2" class=""><span data-v-ee0ef674="" class="capitalize">\n        routine\n      </span></td><td role="cell" aria-colindex="3" class=""><span data-v-ee0ef674=""><span data-v-ee0ef674="">\n          -\n        </span></span></td><td role="cell" aria-colindex="4" class="text-right mx-0 px-0"><span data-v-ee0ef674=""><button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">\n          Show details\n        </button></span></td></tr>'

# %%
driver.find_element_by_class_name('btn').get_attribute("outerHTML")
# Out:
# '<button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">\n          Show details\n        </button>'

# %%
driver.current_url
# Out:
# 'https://www.ajc.com/senior-care-quality-report/homes/addington-place-of-dublin/'

# %%
details_buttons = driver.find_elements_by_xpath("//button[@data-v-ee0ef674=''][@type='button']")
#<input name="continue" type="button" value="Clear" />
#'//div[@id="abc"]//span[@class="btn"]'
for button in details_buttons:
    button.click()
    print(button.get_attribute("outerHTML")+"\n")
    
facilitypage_detailed = BeautifulSoup(driver.page_source, "lxml")
# Out:
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Hide details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Hide details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Hide details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Hide details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Hide details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Hide details
#         </button>

# %%
for inspect in facilitypage_detailed.find_all(class_= "b-table-details"):
    print(inspect.text+"\n")
#<tr id="__BVID__563__details_0_" role="row" class="b-table-details inspections-tr"><td colspan="4" role="cell"><div data-v-ee0ef674="" class="card bg-light"><!----><!----><div data-v-ee0ef674="" class="card-body"><!----><!----><div data-v-ee0ef674=""><p data-v-ee0ef674="" class="m-3 m-md-0">
#            The purpose of this visit was to investigate GA00192704 and conduct the compliance inspection . No rule violations were cited as a result of this investigation.
#          </p> <!----></div> <!----></div><!----><!----></div></td></tr>
# Out:
#             The purpose of this visit was to investigate GA00192704 and conduct the compliance inspection . No rule violations were cited as a result of this investigation.
#
#
#
#             The purpose of this visit was to conduct the initial inspection.  No rule violations were cited as a result of this inspection.
#
#
#
#             The purpose of this visit was to conduct an annual inspection.No rule violations were cited as a result of this inspection.
#
#
#
#             The purpose of this visit was to investigate self reported incident #GA00156376. cited as a result of this inspection.
#
#
#
#             The purpose of this visit was to conduct the initial inspection. No rule violations were cited as a result of this inspection.
#
#
#
#             The purpose of this visit was to conduct an annual inspection.
#             Statute
#               Inspection record text
#                (appears as recorded in state records)
# ...

# %%
facilitypage_detailed.find_all(class_= "b-table-details")[5].find(class_="fa-hitbox")#['data-icon']
# Out:
# <span class="fa-hitbox help flag severity1" data-original-title="" data-v-ee0ef674="" title=""><svg aria-hidden="true" class="svg-inline--fa fa-exclamation-triangle fa-w-18 fa-md text-right" data-icon="exclamation-triangle" data-prefix="fas" data-v-ee0ef674="" focusable="false" role="img" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M569.517 440.013C587.975 472.007 564.806 512 527.94 512H48.054c-36.937 0-59.999-40.055-41.577-71.987L246.423 23.985c18.467-32.009 64.72-31.951 83.154 0l239.94 416.028zM288 354c-25.405 0-46 20.595-46 46s20.595 46 46 46 46-20.595 46-46-20.595-46-46-46zm-43.673-165.346l7.418 136c.347 6.364 5.609 11.346 11.982 11.346h48.546c6.373 0 11.635-4.982 11.982-11.346l7.418-136c.375-6.874-5.098-12.654-11.982-12.654h-63.383c-6.884 0-12.356 5.78-11.981 12.654z" data-v-ee0ef674="" fill="currentColor"></path></svg></span>

# %%
facilitypage_detailed.find_all(class_= "b-table-details")[5].find(class_="fa-hitbox")('svg')[0]['data-icon']
# Out:
# 'exclamation-triangle'

# %%
facilitypage_detailed.find_all(class_= "b-table-details")[5]
# Out:
# <tr class="b-table-details inspections-tr" id="__BVID__563__details_6_" role="row"><td colspan="4" role="cell"><div class="card bg-light" data-v-ee0ef674=""><!-- --><!-- --><div class="card-body" data-v-ee0ef674=""><!-- --><!-- --><div data-v-ee0ef674=""><p class="m-3 m-md-0" data-v-ee0ef674="">
#             The purpose of this visit was to conduct an annual inspection.
#           </p> <hr class="my-3" data-v-ee0ef674=""/></div> <div data-v-ee0ef674=""><div class="table-responsive-sm" data-v-ee0ef674=""><table aria-busy="false" aria-colcount="2" class="table b-table table-striped table-borderless" id="__BVID__571"><!-- --><!-- --><thead class="" role="rowgroup"><!-- --><tr role="row"><th aria-colindex="1" class="pr-0 pr-sm-2 py-2" role="columnheader" scope="col">Statute</th><th aria-colindex="2" class="pb-0 py-sm-2" role="columnheader" scope="col">
#               Inspection record text
# ...

# %%
facilitypage_detailed.find_all(class_= "b-table-details")[5].find_all(role="row")
for record in facilitypage_detailed.find_all(class_= "b-table-details")[5].find_all(role="row"): 
    print(record.text+"\n")
    try: print(record.find(class_="fa-hitbox")('svg')[0]['data-icon'])
    except: continue
    print('\n')
# Out:
# Statute
#               Inspection record text
#                (appears as recorded in state records)
#
#
#               Physical Plant Health and Safety Standards.
#
#                   111-8-62-.13(6)
#                   Based on observation and interview, the facility failed to keep floors in good repair.  Findings include: A tour of Resident # 2 room showed the carpet soiled with dark black spots in front of the recliner. During an interview at 4:00 p.m., Staff G stated he/she will have the carpet cleaned.
#
#
#               Admission.
#
#                   111-8-62-.15(3)
# ...

# %%
#Go back to the previous (main) page:
driver.back()
#if that fails use this: driver.execute_script("window.history.go(-1)")
#or forward: driver.execute_script("window.history.go(+1)")

# %%
link_list = driver.find_elements_by_css_selector('.list-item-name')
link_list[0].get_attribute('outerHTML')
# Out:
# '<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">\n        Addington Place at the Mills\n      </a>'

# %%
#clicking on the link for the first facility details:
link_list[0].click()

# %%
driver.current_url
# Out:
# 'https://www.ajc.com/senior-care-quality-report/homes/addington-place-at-the-mills/'

# %%
#below code finds the first button element with a btn class (any class which includes btn) by css selector method 
# and returns its class:
driver.find_element_by_css_selector(".btn[type='button']").get_attribute("class")
# Out:
# 'btn details-btn btn-secondary btn-sm'

# %%
driver.find_element_by_xpath("//button[@data-v-ee0ef674=''][@type='button']")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="68d1be995e4c439b796db99a48dc2f57", element="a7de38a8-32ea-4a1f-8219-180bc464462f")>

# %%
details_buttons = driver.find_elements_by_xpath("//button[@data-v-ee0ef674=''][@type='button']")
#<input name="continue" type="button" value="Clear" />
#'//div[@id="abc"]//span[@class="btn"]'
for button in details_buttons:
    print(button.get_attribute("outerHTML")+"\n") #prints each button's html code
    button.click()
    
facilitypage_detailed_0 = BeautifulSoup(driver.page_source, "lxml")
# Out:
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# <button data-v-ee0ef674="" type="button" class="btn details-btn btn-secondary btn-sm">
#           Show details
#         </button>
#
# ...

# %%
for row in facilitypage_detailed_0.find_all(class_='inspections-tr'): print(row.text), print("\n")
# Out:
#         12/9/19
#
#         routine
#
#           -
#
#           Hide details
#
#
#
#
#             No rule violations were cited as a result of this inspection.
#
#
#
#
#         6/20/19
#
#         complaint
#
#           1
#
#           Hide details
#
#
#
#  Statute
#               Inspection record text
#                (appears as recorded in state records)
#               Supporting Residents' Rights
#
#                   111-8-62-.25(1)(a)
# ...

# %%
#for row in facilitypage_detailed_0.find_all(class_='inspections-tr'):
facilitypage_detailed_0.find_all(class_='inspections-tr')[2]
# Out:
# <tr aria-describedby="__BVID__545__details_1_" aria-owns="__BVID__545__details_1_" class="inspections-tr b-table-has-details" role="row"><td aria-colindex="1" class="" role="cell"><span data-v-ee0ef674="">
#         6/20/19
#       </span></td><td aria-colindex="2" class="" role="cell"><span class="capitalize" data-v-ee0ef674="">
#         complaint
#       </span></td><td aria-colindex="3" class="" role="cell"><span data-v-ee0ef674=""><span class="text-left" data-v-ee0ef674="">
#           1
# ...

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[2](class_='text-left')[0].text
# Out:
# '\n          1\n           '

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[2](class_='harm1')
# Out:
# [<span class="fa-hitbox help flag harm1" data-original-title="" data-v-ee0ef674="" title=""><svg aria-hidden="true" class="svg-inline--fa fa-h-square fa-w-14 fa-md" data-icon="h-square" data-prefix="fas" data-v-ee0ef674="" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M448 80v352c0 26.51-21.49 48-48 48H48c-26.51 0-48-21.49-48-48V80c0-26.51 21.49-48 48-48h352c26.51 0 48 21.49 48 48zm-112 48h-32c-8.837 0-16 7.163-16 16v80H160v-80c0-8.837-7.163-16-16-16h-32c-8.837 0-16 7.163-16 16v224c0 8.837 7.163 16 16 16h32c8.837 0 16-7.163 16-16v-80h128v80c0 8.837 7.163 16 16 16h32c8.837 0 16-7.163 16-16V144c0-8.837-7.163-16-16-16z" data-v-ee0ef674="" fill="currentColor"></path></svg></span>]

# %%
if facilitypage_detailed_0.find_all(class_='inspections-tr')[2](class_='harm1')!=[]: print('Harm found!')
else: print('No harm!')
# Out:
# Harm found!

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[2](class_='hops')!=[]
# Out:
# False

# %%
print(facilitypage_detailed_0.find_all(class_='inspections-tr')[7].prettify())
# Out:
# <tr class="b-table-details inspections-tr" id="__BVID__545__details_3_" role="row">
#  <td colspan="4" role="cell">
#   <div class="card bg-light" data-v-ee0ef674="">
#    <!-- -->
#    <!-- -->
#    <div class="card-body" data-v-ee0ef674="">
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <div data-v-ee0ef674="">
#      <div class="table-responsive-sm" data-v-ee0ef674="">
#       <table aria-busy="false" aria-colcount="2" class="table b-table table-striped table-borderless" id="__BVID__556">
#        <!-- -->
#        <!-- -->
#        <thead class="" role="rowgroup">
#         <!-- -->
#         <tr role="row">
#          <th aria-colindex="1" class="pr-0 pr-sm-2 py-2" role="columnheader" scope="col">
#           Statute
#          </th>
#          <th aria-colindex="2" class="pb-0 py-sm-2" role="columnheader" scope="col">
#           Inspection record text
#           <br class="d-sm-none" data-v-ee0ef674=""/>
#           <small class="text-muted" data-v-ee0ef674="">
# ...

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[3](class_='pr-0')[1].text
# Out:
# "\n              Supporting Residents' Rights\n               \n                  111-8-62-.25(1)(a)\n                  "

# %%
for flags in facilitypage_detailed_0.find_all(class_='inspections-tr')[3](class_='pr-0')[1](class_='fa-hitbox'):
    print(flags['class'])
    print('Highly severe violation!') if 'severity2' in flags['class'] else None
    print('Harm found!') if 'harm1' in flags['class'] else None
    print('\n')
# Out:
# ['fa-hitbox', 'help', 'flag', 'severity2']
# Highly severe violation!
#
#
# ['fa-hitbox', 'help', 'flag', 'harm1']
# Harm found!

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[3](class_='pr-0')[1](class_='fa-hitbox')[0]#(class_=severity2)
# Out:
# <span class="fa-hitbox help flag severity2" data-original-title="" data-v-ee0ef674="" title=""><svg aria-hidden="true" class="svg-inline--fa fa-exclamation-triangle fa-w-18 fa-md text-right" data-icon="exclamation-triangle" data-prefix="fas" data-v-ee0ef674="" focusable="false" role="img" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M569.517 440.013C587.975 472.007 564.806 512 527.94 512H48.054c-36.937 0-59.999-40.055-41.577-71.987L246.423 23.985c18.467-32.009 64.72-31.951 83.154 0l239.94 416.028zM288 354c-25.405 0-46 20.595-46 46s20.595 46 46 46 46-20.595 46-46-20.595-46-46-46zm-43.673-165.346l7.418 136c.347 6.364 5.609 11.346 11.982 11.346h48.546c6.373 0 11.635-4.982 11.982-11.346l7.418-136c.375-6.874-5.098-12.654-11.982-12.654h-63.383c-6.884 0-12.356 5.78-11.981 12.654z" data-v-ee0ef674="" fill="currentColor"></path></svg></span>

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[5](class_='pr-0')[1](class_='fa-hitbox')[0]['class']
# Out:
# ['fa-hitbox', 'help', 'flag', 'severity1']

# %%
for flags in facilitypage_detailed_0.find_all(class_='inspections-tr')[5](class_='pr-0')[1](class_='fa-hitbox'):
    print(flags['class'])
    print('Highly severe violation!') if 'severity2' in flags['class'] else None
    print('Medium severity violation!') if 'severity1' in flags['class'] else None
    print('Harm found!') if 'harm1' in flags['class'] else None
    print('\n')
# Out:
# ['fa-hitbox', 'help', 'flag', 'severity1']
# Medium severity violation!

# %%
for flags in facilitypage_detailed_0.find_all(class_='inspections-tr')[5](class_='pr-0')[2](class_='fa-hitbox'):
    print(flags['class'])
    print('Highly severe violation!') if 'severity2' in flags['class'] else None
    print('Medium severity violation!') if 'severity1' in flags['class'] else None
    print('Harm found!') if 'harm1' in flags['class'] else None
    print('\n')
# Out:
# ['fa-hitbox', 'help', 'flag', 'severity2']
# Highly severe violation!
#
#
# ['fa-hitbox', 'help', 'flag', 'harm1']
# Harm found!

# %%
for inspection in facilitypage_detailed_0.find_all(class_='inspections-tr')[5](class_='pr-0'):
    print(inspection['class'])
    print(inspection.text)
    for hitbox in inspection(class_='fa-hitbox'):
        try: print('Highly severe violation!') if 'severity2' in hitbox['class'] else None
        except: continue
        try: print('Medium severity violation!') if 'severity1' in hitbox['class'] else None
        except: continue
        try: print('Harm found!') if 'harm1' in hitbox['class'] else None
        except: continue
    print('\n')
# Out:
# ['pr-0', 'pr-sm-2', 'py-2']
# Statute
#
#
# ['pr-0', 'pr-sm-2']
#
#               Physical Plant Health and Safety Standards
#
#                   111-8-62-.13(16)(c)
#
# Medium severity violation!
#
#
# ['pr-0', 'pr-sm-2']
#
#               Medications
#
#                   111-8-62-.20(5)(e)
#
# Highly severe violation!
# Harm found!

# %%
#Next question to myself: Can I add violation text next to these at each line?

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[7]('tbody')[0]('tr')
# Out:
# [<tr class="" role="row"><td aria-colindex="1" class="pr-0 pr-sm-2" role="cell">
#                Services Through Proxy Caregivers
#                <br data-v-ee0ef674=""/> <sub class="text-info" data-v-ee0ef674=""><span class="help" data-original-title="Statute 111-8-100-.04(4)(d)" data-v-ee0ef674="" title="">
#                    111-8-100-.04(4)(d)
# ...

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[7]('tbody')[0]('tr')[1](class_='fa-hitbox')
# Out:
# [<span class="fa-hitbox help flag severity2" data-original-title="" data-v-ee0ef674="" title=""><svg aria-hidden="true" class="svg-inline--fa fa-exclamation-triangle fa-w-18 fa-md text-right" data-icon="exclamation-triangle" data-prefix="fas" data-v-ee0ef674="" focusable="false" role="img" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M569.517 440.013C587.975 472.007 564.806 512 527.94 512H48.054c-36.937 0-59.999-40.055-41.577-71.987L246.423 23.985c18.467-32.009 64.72-31.951 83.154 0l239.94 416.028zM288 354c-25.405 0-46 20.595-46 46s20.595 46 46 46 46-20.595 46-46-20.595-46-46-46zm-43.673-165.346l7.418 136c.347 6.364 5.609 11.346 11.982 11.346h48.546c6.373 0 11.635-4.982 11.982-11.346l7.418-136c.375-6.874-5.098-12.654-11.982-12.654h-63.383c-6.884 0-12.356 5.78-11.981 12.654z" data-v-ee0ef674="" fill="currentColor"></path></svg></span>]

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[7]('tbody')[0]('tr')[1]('td')[1]
# Out:
# <td aria-colindex="2" class="" role="cell">Based on record review and interview, the facility failed to ensure that residents were supervised consistent with their needs. Findings include: During a tour of the facility on 3/27/19 at 10:50 a.m., one staff was observed in memory care with eight residents. A review of the facility's staffing schedule from showed on 5/5/18, 5/6/18, 5/11/18, 12/7/18, 12/22/18, 12/23/18, and 3/9/19 from 7:00 a.m. to 3:00 p.m. two staff worked and one med tech. A review of the facility fire drills from 1/18 to 3/19 showed no fire drills were done from 1/18 to 3/18 and no disaster drills were done from 1/18 to 12/18. A review of the facility's fire drills showed the following drills times were: 1/15/19 2:46 p.m. to 2:53 p.m.=7 minutes 11/10/18 6:58 a.m. to 7:07 a.m.=7 minutes 9/7/18 11:24 a.m.=7 minutes 8/10/18 3:10 p.m. no time noted 4/27/18 4:00 p.m.=9 minutes During an interview on 3/25/19 at 2:10 a.m., BB stated there was only one care staff working in m
# ...

# %%
for irow in facilitypage_detailed_0.find_all(class_='inspections-tr')[7]('tbody')[0]('tr'):
    print(irow('td')[0].text)
    print(irow(class_='help')[0].text.strip())
    #print(irow(class_='pr-0')[0].text)
    #print(irow(class_='fa-hitbox'))
    for hitbox in irow(class_='fa-hitbox'):
        try: print('Highly severe violation!') if 'severity2' in hitbox['class'] else None
        except: continue
        try: print('Medium severity violation!') if 'severity1' in hitbox['class'] else None
        except: continue
        try: print('Harm found!') if 'harm1' in hitbox['class'] else None
        except: continue
        try: print('Violation repeated once!') if 'prev1' in hitbox['class'] else None
        except: continue
    
    print('\n')
    print(irow('td')[1].text)
    print('\n')
# Out:
#               Services Through Proxy Caregivers
#
#                   111-8-100-.04(4)(d)
#
# 111-8-100-.04(4)(d)
#
#
# ...

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[7]('tbody')[0]('tr')[1]('td')[0].text.strip()
# Out:
# 'Staffing\n               \n                  111-8-62-.10(1)(c)'

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[7]('tbody')[0]('tr')[1](class_='help')[0].text.strip()
# Out:
# '111-8-62-.10(1)(c)'

# %%
'\n merhaba      \n'.strip()
# Out:
# 'merhaba'

# %%
facilitypage_detailed_0.find_all(class_='inspections-tr')[6]('td') ##main rows have 'td', details have 'tbody'
# Out:
# [<td aria-colindex="1" class="" role="cell"><span data-v-ee0ef674="">
#          4/12/19
#        </span></td>,
#  <td aria-colindex="2" class="" role="cell"><span class="capitalize" data-v-ee0ef674="">
#          Routine / Complaint
#        </span></td>,
#  <td aria-colindex="3" class="" role="cell"><span data-v-ee0ef674=""><span class="text-left" data-v-ee0ef674="">
#            6
# ...
