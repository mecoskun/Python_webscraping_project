# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
pwd
# Out:
# 'C:\\Users\\Emre\\Downloads\\web_scraping_workshop'

# %%
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()
driver.get("https://www.ajc.com/senior-care-quality-report/homes/")

# %%
soup = BeautifulSoup(driver.page_source, "lxml")

# %%
soup.find(class_="table b-table").find_all("a")
# Out:
# [<a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#          Addington Place at the Mills
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-alpharetta/">
#          Addington Place of Alpharetta
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-brunswick/">
#          Addington Place of Brunswick
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-dublin/">
#          Addington Place of Dublin
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-of-johns-creek/">
#          Addington Place of Johns Creek
#        </a>,
#  <a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/alto-senior-living-alpharetta/">
# ...

# %%
soup.find(class_="table b-table").find_all("td")
# Out:
# [<td aria-colindex="1" class="" role="cell"><span data-original-title="" data-v-052e3680="" title=""><div class="ion danger text-center" data-v-052e3680="" name="md-flag-icon" title="Md Flag Icon"><svg class="ion__svg" height="20" viewbox="0 0 512 512" width="20"><path d="M396 83.2c-13.8 1.7-31.1 4.2-49.6 4.2-28.8 0-55-6.8-81.5-12.2C238 69.7 210.2 64 180.8 64c-58.6 0-78.5 12.1-80.6 13.4L96 80.3V448h48V269.8c9.7-1.2 21.9-2 36.9-2 27.3 0 52.8 10 79.8 15.5 27.6 5.6 56 11.5 86.9 11.5 18.4 0 34.6-2.4 48.4-4 7.5-.9 14-1.7 20-2.7V80.2c-5 1-12.5 2.1-20 3z"></path></svg></div></span></td>,
#  <td aria-colindex="2" class="" role="cell"><a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#          Addington Place at the Mills
#        </a></td>,
# ...

# %%
webpage.text

html_file = open(file = "test.html", mode = "w", encoding = "utf-8")
html_file.write(webpage.text)
html_file.close()

# %%
def invokeDriver():
    from selenium.webdriver.chrome.options import Options
    options = Options()
#     options.add_argument("--headless")
    options.add_argument('log-level=1')     
    driver = webdriver.Chrome(options=options, executable_path="chromedriver.exe")
    driver.implicitly_wait(30)
    print("Chrome Headless Browser Invoked")
    return(driver)

# %%
driver = invokeDriver()
driver.get("https://www.ajc.com/senior-care-quality-report/homes/")
# soup = BeautifulSoup(driver.page_source, "lxml")
# Out:
# Chrome Headless Browser Invoked

# %%
driver.find_element_by_id("__BVID__34__row_addington-place-at-the-mills")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b03000e4f89368b5e8de8717e1f32296", element="8efcf1e9-0356-447a-b7bf-f8141851c01e")>

# %%
driver.find_element_by_xpath("//a[@class='list-item-name']").click()
#<a data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/" class="list-item-name">
#        Addington Place at the Mills
#      </a>

# %%
soup.find("html")
for i in soup.children:
    print(i)
    print("\n")
# Out:
# <html><head><style>.gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}
# </style><link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans:400,500,700" rel="stylesheet" type="text/css"/><style>.gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
# </style><style>.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
# ...

# %%
driver.page_source
# Out:
# '<html><head><style>.gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}\n</style><link type="text/css" rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans:400,500,700"><style>.gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}\n</style><style>.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}\n</style><style>@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style>.gm-style-pbc{transition:opacity ease-in-out;background-col
# ...

# %%
soup.children

# %%
soup.find("html")
for i in soup.children:
    print(i.get_text())
    print("\n")
# Out:
# .gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}
# .gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
# .gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
# ...

# %%
#<tr class="" data-pk="addington-place-at-the-mills" id="__BVID__34__row_addington-place-at-the-mills" role="row">
i = soup('tr',{'data-pk','id'})
i
# Out:
# []

# %%
soup('tr')[1]
# Out:
# <tr class="" data-pk="addington-place-at-the-mills" id="__BVID__34__row_addington-place-at-the-mills" role="row"><td aria-colindex="1" class="" role="cell"><span data-original-title="" data-v-052e3680="" title=""><div class="ion danger text-center" data-v-052e3680="" name="md-flag-icon" title="Md Flag Icon"><svg class="ion__svg" height="20" viewbox="0 0 512 512" width="20"><path d="M396 83.2c-13.8 1.7-31.1 4.2-49.6 4.2-28.8 0-55-6.8-81.5-12.2C238 69.7 210.2 64 180.8 64c-58.6 0-78.5 12.1-80.6 13.4L96 80.3V448h48V269.8c9.7-1.2 21.9-2 36.9-2 27.3 0 52.8 10 79.8 15.5 27.6 5.6 56 11.5 86.9 11.5 18.4 0 34.6-2.4 48.4-4 7.5-.9 14-1.7 20-2.7V80.2c-5 1-12.5 2.1-20 3z"></path></svg></div></span></td><td aria-colindex="2" class="" role="cell"><a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#         Addington Place at the Mills
# ...

# %%
#<tr class="" data-pk="addington-place-at-the-mills" id="__BVID__34__row_addington-place-at-the-mills" 
#    role="row">
#    <td aria-colindex="1" class="" role="cell"><span data-original-title="" data-v-052e3680="" title="">
#    <div class="ion danger text-center" data-v-052e3680="" name="md-flag-icon" title="Md Flag Icon"><svg class="ion__svg" 
#    height="20" viewbox="0 0 512 512" width="20"><path d="M396 83.2c-13.8 1.7-31.1 4.2-49.6 4.2-28.8 0-55-6.8-81.5-12.2C238 69.7 210.2 64 180.8 64c-58.6 0-78.5 12.1-80.6 13.4L96 80.3V448h48V269.8c9.7-1.2 21.9-2 36.9-2 27.3 0 52.8 10 79.8 15.5 27.6 5.6 56 11.5 86.9 11.5 18.4 0 34.6-2.4 48.4-4 7.5-.9 14-1.7 20-2.7V80.2c-5 1-12.5 2.1-20 3z">
#    </path></svg></div></span></td>
#    <td aria-colindex="2" class="" role="cell"><a class="list-item-name" data-v-052e3680="" 
#    href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#         Addington Place at the Mills
#       </a></td>
#    <td aria-colindex="3" class="text-right" role="cell"><span class="fa-hitbox help" data-original-title="" 
#    data-v-052e3680="" title=""><svg aria-hidden="true" class="svg-inline--fa fa-building fa-w-14" data-icon="building" data-prefix="fas" data-v-052e3680="" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M436 480h-20V24c0-13.255-10.745-24-24-24H56C42.745 0 32 10.745 32 24v456H12c-6.627 0-12 5.373-12 12v20h448v-20c0-6.627-5.373-12-12-12zM128 76c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v40c0 6.627-5.373 12-12 12h-40c-6.627 0-12-5.373-12-12V76zm0 96c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v40c0 6.627-5.373 12-12 12h-40c-6.627 0-12-5.373-12-12v-40zm52 148h-40c-6.627 0-12-5.373-12-12v-40c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v40c0 6.627-5.373 12-12 12zm76 160h-64v-84c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v84zm64-172c0 6.627-5.373 12-12 12h-40c-6.627 0-12-5.373-12-12v-40c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v40zm0-96c0 6.627-5.373 12-12 12h-40c-6.627 0-12-5.373-12-12v-40c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v40zm0-96c0 6.627-5.373 12-12 12h-40c-6.627 0-12-5.373-12-12V76c0-6.627 5.373-12 12-12h40c6.627 0 12 5.373 12 12v40z" 
#    data-v-052e3680="" fill="currentColor"></path></svg></span></td>
#    <td aria-colindex="4" class="text-right" role="cell">
#       75
#     </td>
#    <td aria-colindex="5" class="text-muted text-center small d-none d-md-table-cell" role="cell"><small data-v-052e3680="">H11</small></td></tr>,

rates = {}
count = 0
for tr in soup('tr'):
    #symbol_td, rate_td = tr('td')
    #symbol = symbol_td('i')[0]['title']
    #rate = float(rate_td.text)
    #rates[symbol] = rate
    print(tr) if count == 1 else None
    count+=1
# Out:
# <tr class="" data-pk="addington-place-at-the-mills" id="__BVID__34__row_addington-place-at-the-mills" role="row"><td aria-colindex="1" class="" role="cell"><span data-original-title="" data-v-052e3680="" title=""><div class="ion danger text-center" data-v-052e3680="" name="md-flag-icon" title="Md Flag Icon"><svg class="ion__svg" height="20" viewbox="0 0 512 512" width="20"><path d="M396 83.2c-13.8 1.7-31.1 4.2-49.6 4.2-28.8 0-55-6.8-81.5-12.2C238 69.7 210.2 64 180.8 64c-58.6 0-78.5 12.1-80.6 13.4L96 80.3V448h48V269.8c9.7-1.2 21.9-2 36.9-2 27.3 0 52.8 10 79.8 15.5 27.6 5.6 56 11.5 86.9 11.5 18.4 0 34.6-2.4 48.4-4 7.5-.9 14-1.7 20-2.7V80.2c-5 1-12.5 2.1-20 3z"></path></svg></div></span></td><td aria-colindex="2" class="" role="cell"><a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#         Addington Place at the Mills
# ...

# %%
soup('tr')[1]('td')[1].text
# Out:
# '\n        Addington Place at the Mills\n      '

# %%
count=0
for i in soup('tr')[1]('td'):
    print(count)
    print(i)
    print("\n")
    count+=1
# Out:
# 0
# <td aria-colindex="1" class="" role="cell"><span data-original-title="" data-v-052e3680="" title=""><div class="ion danger text-center" data-v-052e3680="" name="md-flag-icon" title="Md Flag Icon"><svg class="ion__svg" height="20" viewbox="0 0 512 512" width="20"><path d="M396 83.2c-13.8 1.7-31.1 4.2-49.6 4.2-28.8 0-55-6.8-81.5-12.2C238 69.7 210.2 64 180.8 64c-58.6 0-78.5 12.1-80.6 13.4L96 80.3V448h48V269.8c9.7-1.2 21.9-2 36.9-2 27.3 0 52.8 10 79.8 15.5 27.6 5.6 56 11.5 86.9 11.5 18.4 0 34.6-2.4 48.4-4 7.5-.9 14-1.7 20-2.7V80.2c-5 1-12.5 2.1-20 3z"></path></svg></div></span></td>
#
#
# 1
# <td aria-colindex="2" class="" role="cell"><a class="list-item-name" data-v-052e3680="" href="/senior-care-quality-report/homes/addington-place-at-the-mills/">
#         Addington Place at the Mills
#       </a></td>
#
#
# 2
# ...

# %%
int(soup('tr')[1]('td')[3].text)
# Out:
# 75

# %%
soup('tr')[1]('td')[2]('svg')[0]['data-icon']
# Out:
# 'building'

# %%
soup('tr')[110]('td')[2]('svg')
# Out:
# [<svg aria-hidden="true" class="svg-inline--fa fa-hospital fa-w-14" data-icon="hospital" data-prefix="fas" data-v-052e3680="" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path class="" d="M448 492v20H0v-20c0-6.627 5.373-12 12-12h20V120c0-13.255 10.745-24 24-24h88V24c0-13.255 10.745-24 24-24h112c13.255 0 24 10.745 24 24v72h88c13.255 0 24 10.745 24 24v360h20c6.627 0 12 5.373 12 12zM308 192h-40c-6.627 0-12 5.373-12 12v40c0 6.627 5.373 12 12 12h40c6.627 0 12-5.373 12-12v-40c0-6.627-5.373-12-12-12zm-168 64h40c6.627 0 12-5.373 12-12v-40c0-6.627-5.373-12-12-12h-40c-6.627 0-12 5.373-12 12v40c0 6.627 5.373 12 12 12zm104 128h-40c-6.627 0-12 5.373-12 12v84h64v-84c0-6.627-5.373-12-12-12zm64-96h-40c-6.627 0-12 5.373-12 12v40c0 6.627 5.373 12 12 12h40c6.627 0 12-5.373 12-12v-40c0-6.627-5.373-12-12-12zm-116 12c0-6.627-5.373-12-12-12h-40c-6.627 0-12 5.373-12 12v40c0 6.627 5.373 12 12 12h40c6.627 0 12-5.373 12-12v-40zM182 96h26v26a6 6 0 0 0 6 6h20a6 6 0 0 0 6
# ...

# %%
soup('tr')[1]('td')[0]
# Out:
# <td aria-colindex="1" class="" role="cell"><span data-original-title="" data-v-052e3680="" title=""><div class="ion danger text-center" data-v-052e3680="" name="md-flag-icon" title="Md Flag Icon"><svg class="ion__svg" height="20" viewbox="0 0 512 512" width="20"><path d="M396 83.2c-13.8 1.7-31.1 4.2-49.6 4.2-28.8 0-55-6.8-81.5-12.2C238 69.7 210.2 64 180.8 64c-58.6 0-78.5 12.1-80.6 13.4L96 80.3V448h48V269.8c9.7-1.2 21.9-2 36.9-2 27.3 0 52.8 10 79.8 15.5 27.6 5.6 56 11.5 86.9 11.5 18.4 0 34.6-2.4 48.4-4 7.5-.9 14-1.7 20-2.7V80.2c-5 1-12.5 2.1-20 3z"></path></svg></div></span></td>

# %%
soup('tr')[3]('td')[0]
# Out:
# <td aria-colindex="1" class="" role="cell"></td>

# %%
soup('tr')[1]('td')[0]('span')[0]('div')[0]['name']
# Out:
# 'md-flag-icon'

# %%
soup('tr')[3]('td')[0]('span')
# Out:
# []

# %%
str.rstrip(soup('tr')[1]('td')[1].text).lstrip()
# Out:
# 'Addington Place at the Mills'

# %%
soup('tr')[1]('td')[1].text.rstrip().lstrip()
# Out:
# 'Addington Place at the Mills'

# %% [markdown]
# # Populating Facilities with Main Info

# %%
array = [None]
array=array+[1]
array=array+['s']
print(array)
array[2]
# Out:
# [None, 1, 's']
# 's'

# %%
value=[1]
try:
    #soup('tr')[3]('td')[0]('span')[0]('div')[0]['name']
    value = value+[1 if soup('tr')[3]('td')[0]('span')[0]('div')[0]['name']=='md-flag-icon' else 0]
except:
    value = value + [0]
value
# Out:
# [1, 0]

# %%
soup('tr')[110]('td')[2]('svg')[0]['data-icon']
# Out:
# 'hospital'

# %%
flagged = []
name = []
hometype = []
beds = []

count = 0
rates = {}

for tr in soup('tr'):
    #Record the name of facility
    try: name = name + [str.rstrip(tr('td')[1].text).lstrip()]
    except: name = name + [""]
    
    #Check flagged status and save:
    try:
        flagged = flagged + [1 if tr('td')[0]('span')[0]('div')[0]['name']=='md-flag-icon' else 0]
    except:
        flagged = flagged + [0]
        
    #Record home type
    try: hometype = hometype + [tr('td')[2]('svg')[0]['data-icon']]
    #hometype = hometype + ['Personal care home' if soup('tr')[1]('td')[2]('svg')[0]['data-icon']=='building' else 'Assisted Living']
    except: hometype = hometype + [""]
        
    #Save number of beds:
    try: beds = beds + [tr('td')[3].text.rstrip().lstrip()]
    except: beds = beds + [""]

    count+=1
    
print(count)
facilities = [name, flagged, hometype, beds]
facilities[0][110]
# Out:
# 399
# 'Cottage Landing Memory Care Building / Cottage Landing'

# %%
#Now we write our data to a csv file:
import csv

# field names  
fields = ['Name', 'Flagged', 'Hometype', 'Beds']  
facilities_rows = zip(*facilities)

filename = "ajc_facilities.csv"

# writing to csv file  
with open(filename, 'w', newline='') as csvfile:  
    # creating a csv writer object  
    csvwriter = csv.writer(csvfile)  
        
    # writing the fields  
    csvwriter.writerow(fields)  
        
    # writing the data rows  
    csvwriter.writerows(facilities_rows)
#csv.write(facilities,'facilities.csv')

# %%
import pandas 
  
# reading the CSV file 
facilities_data = pandas.read_csv('ajc_facilities.csv') 
  
# displaying the contents of the CSV file 
facilities_data.head(10)
#pd.read_csv("pokemon.csv", header =[1, 2])
# Out:
#                              Name  Flagged  Hometype Beds
# 0                             NaN        0       NaN  NaN
# 1    Addington Place at the Mills        1  building   75
# 2   Addington Place of Alpharetta        1  hospital  105
# 3    Addington Place of Brunswick        0  hospital   65
# 4       Addington Place of Dublin        0  hospital   72
# 5  Addington Place of Johns Creek        0  hospital   72
# 6   Alto Senior Living Alpharetta        0  hospital   83
# 7     Alto Senior Living Buckhead        0  hospital   83
# 8     Alto Senior Living Marietta        0  hospital   62
# 9      Antebellum Arlington Place        1  building  120

# %%
int(soup('tr')[110]('td')[3].text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-619a88b57b23> in <module>
# ----> 1 int(soup('tr')[110]('td')[3].text)
#
# ValueError: invalid literal for int() with base 10: '\n      36/48\n    '

# %%
soup('tr')[110]('td')[3].text.rstrip().lstrip()
# Out:
# '36/48'
